# %% [markdown]
# Q.1 Convert a 1D array to a 2D array with 2 rows

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr2d = arr.reshape(2,3)

# %%
arr2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
